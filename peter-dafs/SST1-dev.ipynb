# %% [markdown]
# This notebook is a simple walkthrough of what's possible with XArray for resonant scattering, and a demonstration of the library I've been developing.
#
# The library has a few discrete modules:
#
# 1) File loaders.  These abstract away the details of getting raw data into a raw xarray and correcting the intensity (which lives here because it tends ot be metadata-intensive).  To add support for a new beamline you simply write a class that inherits from FileLoader with one method that opens the file, formats it into an xarray, and cleans up the metadata to include standard terms like exposure, energy, pos_x, pos_th, etc.
#
# (optionally, data preprocessors like HDRSoXS exposure stitching can live between these two steps.)
#
# 2) Integrators.  These abstract away the details of conversion from a raw xarray to a chi,q xarray.  I provide a pyFAI based general purpose integrator (no parameters change within an array) and an energy series integrator (energy changes in an array and is handled efficiently).  Implementing other geometries (e.g. a detector moving) would be handled by subclassing the general integrator.  Implementing other backends (for example, pyGix) is also easy by just supporting the same integrateSingleImage(img) and integrateImageStack(img_stack) methods.
#
# (you can slice the data here easily with standard xarray selector methods - as demonstrated below - or process it)
#
# 3) Fitting.  The fits are very simple to write, I provide a few demos here for lorentz and gauss peaks.  I think there are better curve fitting backends than scipy.optimize.curve_fit (lm_fit?) but that's what I used.

# %% [markdown]
# First, we import the modules we're going to use: (note the hack to put the library directory on the path)

# %%
import sys
sys.path.append("../PyHyperScattering/")

from ALS11012RSoXSLoader import ALS11012RSoXSLoader
from SST1RSoXSLoader import SST1RSoXSLoader

from PFEnergySeriesIntegrator import PFEnergySeriesIntegrator

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Next, we configure the loader with dark images and correction details.

# %%
#loader = ALS11012RSoXSLoader(corr_mode='expt',dark_pedestal=200)
#loader.loadSampleSpecificDarks("../example_data/CCD/PSg/",md_filter={'sampleid':11})

loader = SST1RSoXSLoader(corr_mode='none')

# %% [markdown]
# Let's load an image stack:

# %% [markdown]
# So, next we're going to load a series.  The arguments here are path, dimensions (what axes we want the resulting xarray to have), coordinates (extra axes we generated, as above), and finally a metadata filter to suppress certain files.  In this case we only want a single sample number so we say to ignore files where sampleid is not 11.

# %%
raw_xr = loader.loadFileSeries(
                                '../example_data/SST1/21792/',
                               ['energy','polarization']
                              )
# Out:
# Found 60 files.
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-46.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-11.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-31.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-27.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-2.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-3.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-26.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-30.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-10.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-47.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-37.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-21.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-4.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-8.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-40.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-17.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-16.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-41.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-9.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-5.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-20.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-36.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-19.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-6.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-23.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-35.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-15.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-42.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-39.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-38.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-43.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-14.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-34.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-22.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-7.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-18.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-13.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-44.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-29.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-0.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-25.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-33.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-32.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-24.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-1.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-28.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-45.tiff
# Loading 21792-TP100F-primary-Small Angle CCD Detector_image-12.tiff

# %% [markdown]
# Let's look at this xarray:

# %%
from matplotlib.colors import LogNorm
raw_xr.sel(pix_x=slice(350,400),pix_y=slice(350,400)).sum(['pix_x','pix_y']).plot(x='energy')

# %%
raw_xr.attrs
# Out:
# {'exposure': 2.0,
#  'energy': 556.0,
#  'polarization': 90,
#  'sam_x': 9.0648,
#  'sam_y': -179.9055,
#  'sam_z': 0.0,
#  'sam_th': 180.0,
#  'rsoxs_config': 'saxs',
#  'beamcenter_x': 489.86,
#  'beamcenter_y': 490.75,
#  'sdd': 521.8,
#  'wavelength': 2.2299316546762593e-09,
#  'seq_num': 46,
#  'sampleid': '21792',
#  'dist': 0.5217999999999999,
#  'pixel1': 5.9999999999999995e-05,
#  'pixel2': 5.9999999999999995e-05,
#  'poni1': 0.029445,
#  'poni2': 0.029391599999999997,
#  'rot1': 0,
#  'rot2': 0,
#  'rot3': 0,
#  'dims_unpacked': ['energy', 'polarization']}

# %%
raw_xr.energy
# Out:
# <xarray.DataArray 'energy' (system: 48)>
# array([556. , 526.5, 536.5, 534.5, 514. , 516. , 534. , 536. , 526. , 558. ,
#        539.5, 531.5, 518. , 525. , 544. , 529.5, 529. , 546. , 525.5, 520. ,
#        531. , 539. , 530.5, 522. , 532.5, 538.5, 528.5, 548. , 542. , 540. ,
#        550. , 528. , 538. , 532. , 524. , 530. , 527.5, 552. , 535.5, 510. ,
#        533.5, 537.5, 537. , 533. , 512. , 535. , 554. , 527. ])
# Coordinates:
#   * system        (system) MultiIndex
#   - energy        (system) float64 556.0 526.5 536.5 534.5 ... 535.0 554.0 527.0
#   - polarization  (system) int64 90 90 90 90 90 90 90 ... 90 90 90 90 90 90 90

# %% [markdown]
# OK, let's try integrating this to get something useful!
#
# We set up an integrator - the integrator supports calibrations from Nika and masks from Nika to make life easier.

# %%
integrator = PFEnergySeriesIntegrator(maskmethod = "none",
                                 geomethod = "template_xr",
                                 template_xr = raw_xr,
                                 correctSolidAngle=False,
                                 integration_method='csr') # add ocl to run in opencl
integrator.mask = np.zeros([1024,1026])

# %% [markdown]
# Let's take our test image from before and integrate it:

# %% [markdown]
# We can integrate a whole stack of images really easily:
#
# Note, because we're using the energy series integrator, we're internally pre-allocating integrator objects for each energy then using those for each image for speed.  All these details are abstracted.

# %%
int_xr = integrator.integrateImageStack(raw_xr)

# %%
int_xr.sel(energy=510).plot()

# %%
int_xr.sel(chi=slice(-50,0)).sum('chi').unstack('system').sel(q=slice(0,0.01)).plot(norm=LogNorm(1e3,1e8))

# %%
integrator = None

# %%
int_xr.sel(polarization=90,energy=510).mean('chi').plot(xscale='log',yscale='log')

# %%
import numpy as np
foo_hdr[1].coords['system'].values = foo_hdr[1].coords['system'].values[()][1][np.newaxis]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-093e24743dd8> in <module>
#       1 import numpy as np
# ----> 2 foo_hdr[1].coords['system'].values = foo_hdr[1].coords['system'].values[()][1][np.newaxis]
#
# ~/opt/anaconda3/envs/rsoxs/lib/python3.6/site-packages/xarray/core/common.py in __setattr__(self, name, value)
#     260         """
#     261         try:
# --> 262             object.__setattr__(self, name, value)
#     263         except AttributeError as e:
#     264             # Don't accidentally shadow custom AttributeErrors, e.g.
#
# ~/opt/anaconda3/envs/rsoxs/lib/python3.6/site-packages/xarray/core/dataarray.py in values(self, value)
#     560     @values.setter
#     561     def values(self, value: Any) -> None:
# --> 562         self.variable.values = value
#     563
#     564     @property
#
# ~/opt/anaconda3/envs/rsoxs/lib/python3.6/site-packages/xarray/core/variable.py in values(self, values)
#     448     @values.setter
#     449     def values(self, values):
# --> 450         self.data = values
#     451
#     452     def to_base_variable(self):
#
# ~/opt/anaconda3/envs/rsoxs/lib/python3.6/site-packages/xarray/core/variable.py in data(self, data)
#     343         if data.shape != self.shape:
#     344             raise ValueError(
# --> 345                 f"replacement data must match the Variable's shape. "
#     346                 f"replacement data has shape {data.shape}; Variable has shape {self.shape}"
#     347             )
#
# ValueError: replacement data must match the Variable's shape. replacement data has shape (1,); Variable has shape ()

# %%
raw_xr.coords['system'].values.ndim
# Out:
# 1

# %%
foo_hdr[1].system
# Out:
# <xarray.DataArray 'system' ()>
# array((190.0, 320.01), dtype=object)
# Coordinates:
#     system   object (190.0, 320.01)

# %%
int_hdr = integrator.integrateImageStack(raw_hdr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-145-56ae9a02c4cc> in <module>
# ----> 1 int_hdr = integrator.integrateImageStack(raw_hdr)
#
# ~/OneDrive - National Institute of Standards and Technology (NIST)/Conda/RSoXS-Reduction/NewPyResonantScatteringLibrary/PyHyperScattering/PyHyperScattering/PFEnergySeriesIntegrator.py in integrateImageStack(self, img_stack)
#      51         # restack the reduced data
#      52
# ---> 53         return img_stack.groupby('system').map(self.integrateSingleImage)
#      54
#      55     def createIntegrator(self,en):
#
# ~/opt/anaconda3/envs/rsoxs/lib/python3.6/site-packages/xarray/core/groupby.py in map(self, func, shortcut, args, **kwargs)
#     809             grouped = self._iter_grouped()
#     810         applied = (maybe_wrap_array(arr, func(arr, *args, **kwargs)) for arr in grouped)
# --> 811         return self._combine(applied, shortcut=shortcut)
#     812
#     813     def apply(self, func, shortcut=False, args=(), **kwargs):
#
# ~/opt/anaconda3/envs/rsoxs/lib/python3.6/site-packages/xarray/core/groupby.py in _combine(self, applied, restore_coord_dims, shortcut)
#     828     def _combine(self, applied, restore_coord_dims=False, shortcut=False):
#     829         """Recombine the applied objects like the original."""
# --> 830         applied_example, applied = peek_at(applied)
#     831         coord, dim, positions = self._infer_concat_args(applied_example)
#     832         if shortcut:
#
# ~/opt/anaconda3/envs/rsoxs/lib/python3.6/site-packages/xarray/core/utils.py in peek_at(iterable)
#     180     """
#     181     gen = iter(iterable)
# --> 182     peek = next(gen)
#     183     return peek, itertools.chain([peek], gen)
#     184
#
# ~/opt/anaconda3/envs/rsoxs/lib/python3.6/site-packages/xarray/core/groupby.py in <genexpr>(.0)
#     808         else:
#     809             grouped = self._iter_grouped()
# --> 810         applied = (maybe_wrap_array(arr, func(arr, *args, **kwargs)) for arr in grouped)
#     811         return self._combine(applied, shortcut=shortcut)
#     812
#
# ~/OneDrive - National Institute of Standards and Technology (NIST)/Conda/RSoXS-Reduction/NewPyResonantScatteringLibrary/PyHyperScattering/PyHyperScattering/PFEnergySeriesIntegrator.py in integrateSingleImage(self, img)
#      15         #    use that integrator to reduce
#      16         #    return single reduced frame
# ---> 17         if type(img.energy) != float:
#      18             en = img.energy.values[0]
#      19         else:
#
# ~/opt/anaconda3/envs/rsoxs/lib/python3.6/site-packages/xarray/core/common.py in __getattr__(self, name)
#     231                     return source[name]
#     232         raise AttributeError(
# --> 233             "{!r} object has no attribute {!r}".format(type(self).__name__, name)
#     234         )
#     235
#
# AttributeError: 'DataArray' object has no attribute 'energy'

# %% [markdown]
# A side warning here: if you are using my example data, at this point the memory usage will be kind of insane (~20 GB peak, about 15.5 GB at rest).  We can clean up by tossing the raw data and integrator, which will take us down to something ~2 GB:

# %%
integrator = None

# %% [markdown]
# As with the raw data, we can slice this using standard select commands, and even plot using the core xarray plotting.

# %%
int_xr.sel(energy=270,polarization=100,exposure=1.002, chi=0,method='nearest').plot(xscale='log',yscale='log')

# %% [markdown]
# We can use slicing to punch out energy scans, for example: (this gets a little gross, probably I need an xarray cleanup function)

# %%
pol100chi0 = int_xr.sel(polarization=100,chi=0,method='nearest')
pol100chi0
# Out:
# <xarray.DataArray (system: 92, q: 500)>
# array([[nan, nan, nan, ...,  0.,  0.,  0.],
#        [nan, nan, nan, ...,  0.,  0.,  0.],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])
# Coordinates:
#   * q           (q) float64 2.377e-05 7.132e-05 0.0001189 ... 0.0237 0.02375
#     chi         float64 0.483
#   * system      (system) MultiIndex
#   - energy      (system) float64 310.0 289.5 282.8 284.8 ... 284.0 286.0 280.0
#   - exposure    (system) float64 1.002 1.002 0.003 0.102 ... 0.102 0.102 0.003
#   - filenumber  (system) int64 92 84 10 47 51 6 71 26 ... 91 29 68 87 13 44 52 5
# Attributes:
#     SIMPLE:                         True
#     BITPIX:                         8
#     NAXIS:                          0
#     EXTEND:                         True
#     COMMENT:                            and Astrophysics', volume 376, page 3...
#     EXPOSURE:                       1.0
#     TEMP:                           -44.5
#     RINGCRNT:                       500.060339355469
#     DATE:                           2019-12-05T17:18:47
#     ROI_L:                          1309
#     ROI_T:                          526
#     ROI_R:                          2539
#     ROI_B:                          1627
#     EPU Polarization:               100.0
#     Coolstage Temp C:               0.0
#     CCD Temperature:                -45.0
#     Beam Current:                   500.132818603515
#     TEY signal:                     -0.00136385642089821
#     IZERO:                          -0.698759368088832
#     Photodiode:                     -0.0174415487398088
#     AI 0:                           0.0105281275274171
#     AI 3 Izero:                     0.25842225556108
#     AI 5:                           0.257279214499274
#     AI 6 BeamStop:                  -35.2255056410498
#     AI 7:                           -0.00296600067684033
#     Temperature Controller:         0.0
#     PZT Shutter:                    0.0
#     Pause Trigger:                  0.0
#     LV Memory:                      345552.0
#     Time Stamp Error:               -0.0127792358398438
#     Time Stamp Transmit Time:       1.27750742062926
#     Time Stamp Server Time:         0.722492579370737
#     Sample Azimuthal Rotation:      0.0
#     Piezo Vertical:                 0.0
#     Piezo Horiz:                    0.0
#     Sample X:                       0.802
#     Sample Y:                       -16.977
#     Sample Z:                       -2.0
#     Sample Theta:                   90.0
#     Sample Y Scaled:                -15.9531616230824
#     CCD Theta:                      -1.219
#     Beam Stop:                      -10.447
#     Pollux CCD X:                   0.0
#     Pollux CCD Y:                   0.0
#     CCD X:                          99.83
#     CCD Y:                          100.0
#     CCD Temperature Setpoint:       -45.0
#     T-2T:                           90.0
#     Beamline Energy:                309.999784281053
#     Mono 101 Grating:               -36.1801606083782
#     Beamline Energy Goal:           0.0
#     Entrance Slit width:            35.0
#     Exit Slit Left:                 3608.0
#     Exit Slit Right:                8910.0
#     Horizontal Exit Slit Size:      1500.0
#     Horizontal Exit Slit Position:  -700.0
#     Vertical Exit Slit Size:        25.9000000000001
#     Vertical Exit Slit Position:    0.259999999999991
#     EPU Gap:                        28.6995375
#     EPU Z:                          -1.52587887711393e-09
#     Mono Energy:                    309.999784281053
#     M103 Yaw:                       2.205
#     M103 Bend Up:                   0.5595
#     M103 Bend Down:                 1.0033
#     M101 Feedback:                  0.0
#     M101 Horizontal Deflection:     2.002
#     M101 Vertical Deflection:       -13.504
#     Vertical Slit Position:         0.259999999999991
#     Vertical Slit Size:             25.9000000000001
#     Horizontal Slit Position:       -700.0
#     Mono 101 Vessel:                25.0
#     Horizontal Slit Size:           1500.0
#     Diag 106:                       95.0
#     M121 Translation:               17.99971
#     PiezoShutter Trans:             18.9567857142857
#     Higher Order Suppressor:        7.50014446251372
#     AO 0:                           0.0
#     AO 1:                           0.0
#     OSP Adjustment:                 0.0
#     CCD Shutter Inhibit:            0.0
#     CCD Shutter Control:            0.0
#     Upstream JJ Vert Aperture:      0.25
#     Upstream JJ Vert Trans:         -0.762290396341463
#     Upstream JJ Horz Aperture:      0.25
#     Upstream JJ Horz Trans:         -1.34518038617886
#     Middle JJ Vert Aperture:        0.4
#     Middle JJ Vert Trans:           -0.723732215447154
#     Middle JJ Horz Aperture:        0.4
#     Middle JJ Horz Trans:           2.14328633130081
#     In-Chamber JJ Vert Aperture:    0.8001016002032
#     In-Chamber JJ Vert Trans:       -0.239268478536957
#     In-Chamber JJ Horz Aperture:    0.8001016002032
#     In-Chamber JJ Horz Trans:       -2.03759207518415
#     Sample Number:                  11.0
#     Coolstage:                      0.0
#     exposure:                       1.002
#     energy:                         310.0
#     polarization:                   100.0
#     sam_x:                          0.802
#     sam_y:                          -16.977
#     sam_z:                          -2.0
#     sam_th:                         90.0
#     sampleid:                       11.0
#     wavelength:                     3.999490322580645e-09
#     det_x:                          99.83
#     det_y:                          100.0
#     det_th:                         -1.22
#     filenumber:                     92
#     dims_unpacked:                  ['energy', 'polarization', 'exposure', 'f...

# %% [markdown]
# The one crude thing we have to do - remember that 'filenumber' axis we put in?  We need to get rid of it for auto-plotting to work... so we'll unstack the system multiindex (like a compound axis, done above) and select all values of the filenumber coordinate.  We also need to put the array in the right order for auto-plotting.

# %%
pol100chi0 = pol100chi0.sel(filenumber=slice(0,500)).sel(exposure=slice(0.08,0.11))
pol100chi0 = pol100chi0.drop('chi').sortby('energy').sortby('q')
pol100chi0
# Out:
# <xarray.DataArray (energy: 45, q: 500)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ...,  0.,  0.,  0.],
#        [nan, nan, nan, ...,  0.,  0.,  0.],
#        [nan, nan, nan, ...,  0.,  0.,  0.]])
# Coordinates:
#   * q        (q) float64 2.377e-05 7.132e-05 0.0001189 ... 0.0237 0.02375
#   * energy   (energy) float64 270.0 270.0 280.0 281.0 ... 310.0 315.0 320.0
# Attributes:
#     SIMPLE:                         True
#     BITPIX:                         8
#     NAXIS:                          0
#     EXTEND:                         True
#     COMMENT:                            and Astrophysics', volume 376, page 3...
#     EXPOSURE:                       1.0
#     TEMP:                           -44.5
#     RINGCRNT:                       500.060339355469
#     DATE:                           2019-12-05T17:18:47
#     ROI_L:                          1309
#     ROI_T:                          526
#     ROI_R:                          2539
#     ROI_B:                          1627
#     EPU Polarization:               100.0
#     Coolstage Temp C:               0.0
#     CCD Temperature:                -45.0
#     Beam Current:                   500.132818603515
#     TEY signal:                     -0.00136385642089821
#     IZERO:                          -0.698759368088832
#     Photodiode:                     -0.0174415487398088
#     AI 0:                           0.0105281275274171
#     AI 3 Izero:                     0.25842225556108
#     AI 5:                           0.257279214499274
#     AI 6 BeamStop:                  -35.2255056410498
#     AI 7:                           -0.00296600067684033
#     Temperature Controller:         0.0
#     PZT Shutter:                    0.0
#     Pause Trigger:                  0.0
#     LV Memory:                      345552.0
#     Time Stamp Error:               -0.0127792358398438
#     Time Stamp Transmit Time:       1.27750742062926
#     Time Stamp Server Time:         0.722492579370737
#     Sample Azimuthal Rotation:      0.0
#     Piezo Vertical:                 0.0
#     Piezo Horiz:                    0.0
#     Sample X:                       0.802
#     Sample Y:                       -16.977
#     Sample Z:                       -2.0
#     Sample Theta:                   90.0
#     Sample Y Scaled:                -15.9531616230824
#     CCD Theta:                      -1.219
#     Beam Stop:                      -10.447
#     Pollux CCD X:                   0.0
#     Pollux CCD Y:                   0.0
#     CCD X:                          99.83
#     CCD Y:                          100.0
#     CCD Temperature Setpoint:       -45.0
#     T-2T:                           90.0
#     Beamline Energy:                309.999784281053
#     Mono 101 Grating:               -36.1801606083782
#     Beamline Energy Goal:           0.0
#     Entrance Slit width:            35.0
#     Exit Slit Left:                 3608.0
#     Exit Slit Right:                8910.0
#     Horizontal Exit Slit Size:      1500.0
#     Horizontal Exit Slit Position:  -700.0
#     Vertical Exit Slit Size:        25.9000000000001
#     Vertical Exit Slit Position:    0.259999999999991
#     EPU Gap:                        28.6995375
#     EPU Z:                          -1.52587887711393e-09
#     Mono Energy:                    309.999784281053
#     M103 Yaw:                       2.205
#     M103 Bend Up:                   0.5595
#     M103 Bend Down:                 1.0033
#     M101 Feedback:                  0.0
#     M101 Horizontal Deflection:     2.002
#     M101 Vertical Deflection:       -13.504
#     Vertical Slit Position:         0.259999999999991
#     Vertical Slit Size:             25.9000000000001
#     Horizontal Slit Position:       -700.0
#     Mono 101 Vessel:                25.0
#     Horizontal Slit Size:           1500.0
#     Diag 106:                       95.0
#     M121 Translation:               17.99971
#     PiezoShutter Trans:             18.9567857142857
#     Higher Order Suppressor:        7.50014446251372
#     AO 0:                           0.0
#     AO 1:                           0.0
#     OSP Adjustment:                 0.0
#     CCD Shutter Inhibit:            0.0
#     CCD Shutter Control:            0.0
#     Upstream JJ Vert Aperture:      0.25
#     Upstream JJ Vert Trans:         -0.762290396341463
#     Upstream JJ Horz Aperture:      0.25
#     Upstream JJ Horz Trans:         -1.34518038617886
#     Middle JJ Vert Aperture:        0.4
#     Middle JJ Vert Trans:           -0.723732215447154
#     Middle JJ Horz Aperture:        0.4
#     Middle JJ Horz Trans:           2.14328633130081
#     In-Chamber JJ Vert Aperture:    0.8001016002032
#     In-Chamber JJ Vert Trans:       -0.239268478536957
#     In-Chamber JJ Horz Aperture:    0.8001016002032
#     In-Chamber JJ Horz Trans:       -2.03759207518415
#     Sample Number:                  11.0
#     Coolstage:                      0.0
#     exposure:                       1.002
#     energy:                         310.0
#     polarization:                   100.0
#     sam_x:                          0.802
#     sam_y:                          -16.977
#     sam_z:                          -2.0
#     sam_th:                         90.0
#     sampleid:                       11.0
#     wavelength:                     3.999490322580645e-09
#     det_x:                          99.83
#     det_y:                          100.0
#     det_th:                         -1.22
#     filenumber:                     92
#     dims_unpacked:                  ['energy', 'polarization', 'exposure', 'f...

# %%
from matplotlib.colors import LogNorm
pol100chi0.plot(norm=LogNorm(1e-1,5e5))
# Out:
# /Users/pab2/opt/anaconda3/envs/rsoxs/lib/python3.6/site-packages/matplotlib/colors.py:1171: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %% [markdown]
# For fitting, we can use the xarray split-apply-combine paradigm to automate things nicely.
# Skipping the array prep for now, but here is the syntax.  This part is very much work in progress.

# %%
import Fitting
from Fitting import fit_lorentz_bg

# %%
lor0p002_p100_e0p1_chi0 = (pol100e0p1
       .coarsen(chi=10).mean()      #you can either coarsen chi (where number is an integer number of bins
                                     #over which to do a moving average), or
       #.sel(chi=0,method='nearest')  #you can just select a single chi stripe, if you do this, you can't stack
       .stack(echi=['energy','chi']) 
       .sel(q=slice(0.0018,0.0025))
       .groupby('echi')
       .map(fit_lorentz_bg,guess=[0,0,0.0002,2e-8],pos_int_override=True)
       .unstack('echi'))
lor0p002_p100_e0p1_chim90 = (pol100e0p1
       #.coarsen(chi=15).mean()      #you can either coarsen chi (where number is an integer number of bins
                                     #over which to do a moving average), or
       .sel(chi=-90,method='nearest')  #you can just select a single chi stripe, if you do this, you can't stack
       .stack(echi=['energy'])#,'chi'])
       .sel(q=slice(0.0018,0.0025))
       .groupby('echi')
       .map(fit_lorentz,guess=[0,0,0.0002],pos_int_override=True)
       .unstack('echi'))

lor0p002_p100_e0p1_chim90 = (pol100e0p1
       .sel(chi=-90,method='nearest')  #you can just select a single chi stripe, if you do this, you can't stack
       .sel(q=slice(0.0018,0.0025))
       .map(fit_lorentz,guess=[0,0,0.0002],pos_int_override=True)
# Out:
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (270.0,)
# Fit completed, coeff = [5.58710261e-09 2.14143365e-03 1.28799515e-04 4.10084458e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (280.0,)
# Fit completed, coeff = [1.22653626e-09 2.14293984e-03 1.36948357e-04 5.79321512e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (281.0,)
# Fit completed, coeff = [5.35843435e-10 2.19031094e-03 1.05557154e-04 2.52267420e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (282.0,)
# Fit completed, coeff = [ 2.63434223e-10  2.10201348e-03  5.36061360e-04 -1.38503819e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (282.26,)
# Fit completed, coeff = [-1.72461969e-10  2.41849286e-03 -8.46953771e-05  2.03924580e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (282.5,)
# Fit completed, coeff = [1.68711876e-10 2.16529154e-03 7.69586982e-05 2.23109055e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (282.75,)
# Fit completed, coeff = [4.58094244e-10 2.17041243e-03 7.93580148e-05 3.59607272e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (283.0,)
# Fit completed, coeff = [5.20371318e-10 2.15727492e-03 9.87264991e-05 6.51497710e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (283.25,)
# Fit completed, coeff = [ 1.18686133e-09  2.15827852e-03 -6.63248836e-05  1.03678897e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (283.5,)
# Fit completed, coeff = [1.77854228e-09 2.15608531e-03 7.65845677e-05 1.55762690e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (283.76,)
# Fit completed, coeff = [2.25865768e-09 2.15647261e-03 7.38414649e-05 2.34180051e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (284.0,)
# Fit completed, coeff = [2.90305777e-09 2.15370027e-03 1.08949519e-04 3.08806619e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (284.25,)
# Fit completed, coeff = [4.05517156e-09 2.14885023e-03 1.04046524e-04 3.75119034e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (284.5,)
# Fit completed, coeff = [6.15499152e-09 2.16215790e-03 8.22076864e-05 4.60440516e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (284.75,)
# Fit completed, coeff = [7.34372727e-09 2.15958267e-03 1.03578578e-04 6.23909139e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (285.01,)
# Fit completed, coeff = [1.19374129e-08 2.16262394e-03 1.16168718e-04 9.05915589e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (285.25,)
# Fit completed, coeff = [5.76230312e-09 2.16957733e-03 1.27164516e-04 2.50291427e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (285.51,)
# Fit completed, coeff = [7.09860734e-09 2.16412540e-03 1.33498189e-04 3.15745029e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (285.75,)
# Fit completed, coeff = [9.82008376e-09 2.15842537e-03 1.28383478e-04 5.40970211e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (286.0,)
# Fit completed, coeff = [7.85616070e-09 2.15050043e-03 1.20218662e-04 5.55971375e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (286.25,)
# Fit completed, coeff = [3.71973817e-09 2.14850007e-03 1.13814360e-04 2.69529988e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (286.5,)
# Fit completed, coeff = [7.93778189e-10 2.14476867e-03 7.38829736e-05 1.08199991e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (286.75,)
# Fit completed, coeff = [ 5.43911819e-07  1.96998006e-03 -2.98557232e-02 -5.43603852e-07]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (287.01,)
# Fit completed, coeff = [1.75970181e-09 2.14938380e-03 1.27013835e-04 8.24190257e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (287.25,)
# Fit completed, coeff = [3.43426836e-09 2.16565240e-03 1.12385620e-04 2.27087485e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (287.5,)
# Fit completed, coeff = [3.42021359e-09 2.15622621e-03 1.12802054e-04 1.57514516e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (287.76,)
# Fit completed, coeff = [2.00440364e-09 2.16403956e-03 1.15007954e-04 1.20428402e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (288.01,)
# Fit completed, coeff = [1.44783319e-09 2.17897879e-03 9.43510149e-05 1.03391504e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (288.26,)
# Fit completed, coeff = [1.58937212e-09 2.15900117e-03 1.04111779e-04 8.40203514e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (288.5,)
# Fit completed, coeff = [1.81880924e-09 2.16719944e-03 9.69141834e-05 8.42546575e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (288.75,)
# Fit completed, coeff = [2.95386713e-09 2.17104370e-03 9.08884735e-05 1.22081071e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (289.01,)
# Fit completed, coeff = [2.67873602e-09 2.16518753e-03 1.16385539e-04 1.30723606e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (289.25,)
# Fit completed, coeff = [2.05536067e-09 2.16172088e-03 1.15829713e-04 1.17571706e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (289.51,)
# Fit completed, coeff = [1.60259760e-09 2.14901365e-03 1.77407871e-04 5.06613206e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (289.75,)
# Fit completed, coeff = [1.15774025e-09 2.16387591e-03 1.12631966e-04 6.04225315e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (290.0,)
# Fit completed, coeff = [7.19118711e-10 2.16688746e-03 1.10091367e-04 2.74604747e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (291.0,)
# Fit completed, coeff = [1.11675213e-09 2.16705104e-03 1.10432493e-04 5.30150336e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (292.01,)
# Fit completed, coeff = [1.10193799e-09 2.16688950e-03 1.19282331e-04 4.42936289e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (295.01,)
# Fit completed, coeff = [1.97451276e-09 2.16978083e-03 1.20560125e-04 7.83796776e-10]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (300.01,)
# Fit completed, coeff = [4.17692020e-09 2.16508658e-03 1.29356197e-04 1.72181712e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (305.0,)
# Fit completed, coeff = [1.28192722e-08 2.14860117e-03 1.28842141e-04 5.27767069e-09]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (310.0,)
# Fit completed, coeff = [2.82287987e-08 2.15635249e-03 1.22741417e-04 1.41310110e-08]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (315.01,)
# Fit completed, coeff = [4.15263561e-08 2.14799618e-03 1.35590234e-04 1.76723278e-08]
# Starting fit on Coordinates:
#     chi      float64 0.483
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (320.0,)
# Fit completed, coeff = [4.69134544e-08 2.14987741e-03 1.31219724e-04 1.97019688e-08]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (270.0,)
# Fit completed, coeff = [1.09422197e-08 1.55449832e-03 8.50291449e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (280.0,)
# Fit completed, coeff = [1.37297018e-09 1.63186513e-03 9.80073239e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (281.0,)
# Fit failed to converge
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (282.0,)
# Fit completed, coeff = [1.23621255e-10 1.73874873e-03 1.27881377e-03]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (282.26,)
# Fit completed, coeff = [3.83162487e-10 1.33167036e-03 1.09185186e-03]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (282.5,)
# Fit failed to converge
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (282.75,)
# Fit failed to converge
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (283.0,)
# Fit failed to converge
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (283.25,)
# Fit completed, coeff = [2.86961973e-09 1.67874305e-03 8.70184742e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (283.5,)
# Fit completed, coeff = [6.47480916e-09 1.11977204e-03 9.51394101e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (283.76,)
# Fit completed, coeff = [8.14474411e-09 1.32323385e-03 8.76175917e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (284.0,)
# Fit completed, coeff = [8.03336936e-09 1.61358443e-03 8.63739046e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (284.25,)
# Fit completed, coeff = [3.82168093e-08 6.40398128e-04 7.15367684e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (284.5,)
# Fit completed, coeff = [1.53600997e-08 1.39951471e-03 8.86727083e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (284.75,)
# Fit completed, coeff = [2.19826433e-08 1.36133921e-03 8.20041561e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (285.01,)
# Fit completed, coeff = [2.77444751e-08 1.63594595e-03 6.34782787e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (285.25,)
# Fit completed, coeff = [7.46707139e-09 1.78364493e-03 5.37596794e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (285.51,)
# Fit completed, coeff = [1.00897845e-08 1.74470124e-03 5.84500166e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (285.75,)
# Fit completed, coeff = [1.54941703e-08 1.80553678e-03 5.83918426e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (286.0,)
# Fit completed, coeff = [1.80600512e-08 1.61300224e-03 7.38146115e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (286.25,)
# Fit completed, coeff = [8.95753410e-09 1.56223242e-03 8.70804838e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (286.5,)
# Fit completed, coeff = [3.00835217e-09 1.86224683e-03 5.82980258e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (286.75,)
# Fit completed, coeff = [5.23633246e-10 1.71231989e-03 7.10088594e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (287.01,)
# Fit completed, coeff = [1.58306278e-09 1.79322317e-03 6.78400227e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (287.25,)
# Fit completed, coeff = [4.36530403e-09 1.79205839e-03 6.85847731e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (287.5,)
# Fit completed, coeff = [3.96174934e-09 1.57165319e-03 8.37330374e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (287.76,)
# Fit completed, coeff = [2.55045637e-09 1.81227542e-03 6.60751513e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (288.01,)
# Fit failed to converge
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (288.26,)
# Fit completed, coeff = [1.88052045e-09 1.64792126e-03 8.81227280e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (288.5,)
# Fit completed, coeff = [1.76047009e-09 1.77567491e-03 8.63801090e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (288.75,)
# Fit completed, coeff = [2.87145828e-09 1.77278816e-03 7.32054067e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (289.01,)
# Fit completed, coeff = [2.99997105e-09 1.77506745e-03 7.65236160e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (289.25,)
# Fit completed, coeff = [2.46911861e-09 1.79152112e-03 7.59025391e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (289.51,)
# Fit completed, coeff = [1.80076988e-09 1.93585257e-03 5.19454738e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (289.75,)
# Fit completed, coeff = [1.27409402e-09 1.86848138e-03 7.03008929e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (290.0,)
# Fit completed, coeff = [7.19052430e-10 1.81897237e-03 6.15248197e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (291.0,)
# Fit completed, coeff = [1.14961183e-09 1.79185376e-03 7.36740943e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (292.01,)
# Fit completed, coeff = [1.02910713e-09 1.94342147e-03 5.02389280e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (295.01,)
# Fit completed, coeff = [1.86536491e-09 1.85258389e-03 6.24658633e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (300.01,)
# Fit completed, coeff = [4.63479048e-09 1.68782258e-03 7.57268943e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (305.0,)
# Fit completed, coeff = [1.43050917e-08 1.75577679e-03 6.57277332e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (310.0,)
# Fit completed, coeff = [3.47135990e-08 1.76616335e-03 6.69001024e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (315.01,)
# Fit completed, coeff = [4.89067025e-08 1.79648711e-03 6.48238812e-04]
# Starting fit on Coordinates:
#     chi      float64 -89.51
#   * q        (q) float64 0.001839 0.001888 0.001937 ... 0.002426 0.002475
#     echi     object (320.0,)
# Fit completed, coeff = [5.39436040e-08 1.83343957e-03 6.10606845e-04]
# CPU times: user 15 s, sys: 195 ms, total: 15.2 s
# Wall time: 15.3 s
